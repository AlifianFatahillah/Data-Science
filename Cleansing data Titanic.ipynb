# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from feature_engine.imputation import RandomSampleImputer
from feature_engine.imputation import EndTailImputer

# %%
df = pd.read_csv(r"C:\Users\Asani\Documents\DATA PELATIHAN\titanic.csv")
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# ## Melihat kolom mana yang kosong

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Mengganti kolom Age dengan Rata-rata

# %%
mean_value = df["Age"].mean()
mean_value
# Out:
# 29.69911764705882

# %%
df["Age"].fillna(mean_value, inplace=True)
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  29.699118
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# ...

# %% [markdown]
# ## Mengganti kolom Age dengan nilai random

# %%
df1 = pd.read_csv(r"C:\Users\Asani\Documents\DATA PELATIHAN\titanic.csv")

Random = 30
df1["Age"].fillna(Random, inplace=True)
df1.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  30.0      0
# ...

# %% [markdown]
# ## Mengganti semua kolom kosong (Age, Cabin, Emberked) dengan Modus

# %%
df3 = pd.read_csv(r"C:\Users\Asani\Documents\DATA PELATIHAN\titanic.csv")

imp = SimpleImputer(strategy="most_frequent")

test_T1= imp.fit_transform(df3)

test_T2=pd.DataFrame(test_T1)
test_T2
# Out:
#       0  1  2                                                  3       4   \
# 0      1  0  3                            Braund, Mr. Owen Harris    male
# 1      2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2      3  1  3                             Heikkinen, Miss. Laina  female
# 3      4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4      5  0  3                           Allen, Mr. William Henry    male
# ..   ... .. ..                                                ...     ...
# 886  887  0  2                              Montvila, Rev. Juozas    male
# 887  888  1  1                       Graham, Miss. Margaret Edith  female
# 888  889  0  3           Johnston, Miss. Catherine Helen "Carrie"  female
# 889  890  1  1                              Behr, Mr. Karl Howell    male
# 890  891  0  3                                Dooley, Mr. Patrick    male
#
#        5  6  7                 8        9        10 11
# ...

# %% [markdown]
# ## Menganti semua nilai NaN pada semua kolom menggunakan Random semple

# %%
df4 = pd.read_csv(r"C:\Users\Asani\Documents\DATA PELATIHAN\titanic.csv")


imputere = RandomSampleImputer(random_state=50)

imputere.fit(df4)

test_T = imputere.transform(df4)
test_T.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  21.0      0
# ...

# %% [markdown]
# ## Mengganti nilai kolom Age menggunakan End of Tail

# %%
df5 = pd.read_csv(r"C:\Users\Asani\Documents\DATA PELATIHAN\titanic.csv")

impt = EndTailImputer(imputation_method = "gaussian", tail="right")
impt.fit(df5)

test_T5 = impt.transform(df5)
test_T5.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex       Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.00000      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00000      1
# 2                             Heikkinen, Miss. Laina  female  26.00000      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00000      1
# 4                           Allen, Mr. William Henry    male  35.00000      0
# 5                                   Moran, Mr. James    male  73.27861      0
# ...
